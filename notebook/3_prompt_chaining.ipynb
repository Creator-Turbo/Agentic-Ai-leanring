# %%
print("hello")
# Out:
# hello

# %%
from langgraph.graph import StateGraph, START, END
from langchain_openai import ChatOpenAI

from typing import TypedDict
from dotenv import load_dotenv
import os

# %%
load_dotenv()
# Out:
# True

# %%
# Read variables
OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")
OPENAI_API_BASE = os.getenv("OPENAI_API_BASE")

# %%
# Store them in environment variables
load_dotenv()
LM_STUDIO_BASE_URL = os.environ.get('LM_STUDIO_BASE_URL')
# os.environ['LM_STUDIO_BASE_URL'] = LM_STUDIO_BASE_URL

# %%
# Create LLM
llm = ChatOpenAI(
    openai_api_key=OPENAI_API_KEY,
    openai_api_base=OPENAI_API_BASE,
    model="smallthinker-3b",
    temperature=0.7
)

print(llm.invoke("hello"))
# Out:
# content="Hello! How can I help you today? If you have any questions or need assistance with something, feel free to ask. I'm here to help." additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 32, 'prompt_tokens': 20, 'total_tokens': 52, 'completion_tokens_details': None, 'prompt_tokens_details': None}, 'model_provider': 'openai', 'model_name': 'smallthinker-3b-preview', 'system_fingerprint': 'smallthinker-3b-preview', 'id': 'chatcmpl-i4w2nmzb3m3wq7tameg4e', 'finish_reason': 'stop', 'logprobs': None} id='lc_run--019d8fca-471a-7460-be69-32c4e8952f78-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 20, 'output_tokens': 32, 'total_tokens': 52, 'input_token_details': {}, 'output_token_details': {}}

# %%
class BlogState(TypedDict):
    title: str 
    outline : str 
    content : str

# %%
def create_outline(state: BlogState) -> BlogState:

    # fetch title 
    title = state['title']

    # create llm gen outline 
    prompt = f"Generate a detailed outline for a blog on the topic - {title}"
    outline = llm.invoke(prompt).content 


    # update state 
    state['outline'] = outline 

    return state

# %%
def create_blog(state: BlogState) -> BlogState:

    title = state['title']
    outline = state['outline']

    prompt = f'Write a detailed blog on the title - {title} using the follwing outline \n {outline}'

    content = llm.invoke(prompt).content

    state['content'] = content

    return state

# %%
graph = StateGraph(BlogState)


# nodes 

graph.add_node("create_outline", create_outline)
graph.add_node("create_blog", create_blog)



# edges
graph.add_edge(START, 'create_outline')
graph.add_edge('create_outline', 'create_blog')
graph.add_edge('create_blog', END)

workflow = graph.compile()

# %%
initial_state  = {'title': 'Rise of AI in India'}

final_state = workflow.invoke(initial_state)

print(final_state)
# Out:
# {'title': 'Rise of AI in India', 'outline': "I've been tasked with creating a detailed outline for a blog about the rise of AI in India. I need to make sure that the content is informative, engaging, and covers all the key aspects of how artificial intelligence has impacted the country. Let me start by brainstorming some main points that should be included.\n\nFirst off, I think it's important to introduce what AI is and why it's significant, especially in a context like India. Maybe include some basic definitions and perhaps touch on its global impact as well. This will help readers who might not be familiar with the technology understand the importance of AI in today's world.\n\nNext, I should look into the history of AI development in India. When did it start? What were the initial milestones? Who are the key players or institutions involved in AI research and development here? Understanding the background can provide context for how far we've come and where we're headed.\n\nMoving on to current trends and applications of AI in India. This could include sectors like healthcare, finance, education, transportation, etc., where AI is making a significant impact. For each sector, I should mention specific examples or companies that are leading the way with AI solutions. It might also be useful to discuss any challenges these industries are facing due to AI implementation and how they're being addressed.\n\nMoreover, discussing the role of government in fostering AI development would be insightful. Are there any policies or initiatives launched by the Indian government to promote AI? How is funding being allocated for AI research and innovation? What about collaborations with international organizations or tech giants?\n\nEducation and skill development are also crucial aspects. With AI becoming increasingly prevalent, there's a need for skilled workforce. I should look into programs that are in place to train people in AI-related skills, both at the undergraduate and graduate levels as well as through non-formal courses.\n\nEthical considerations and challenges cannot be overlooked. As AI advances, there are issues related to privacy, job displacement, bias in algorithms, and more that need to be addressed. It would be valuable to explore these topics and see how India is tackling them.\n\nFurthermore, the impact of AI on society and economy is a broad topic. I should consider both sides—how AI is creating new opportunities and disrupting existing ones—and analyze whether it's leading to overall progress or inequality.\n\nIn terms of structure, maybe start with an introduction to AI and its importance, followed by history in India, current trends, government initiatives, education and skill development, ethical considerations, impact on society and economy, and finally, a conclusion summarizing the key points and perhaps looking ahead to future prospects.\n\nLet me try sketching this out in a more organized way:\n\nI. Introduction\n\n* A. Brief explanation of AI\n* B. Significance of AI in today's world\n* C. Importance of studying AI in India\n\nII. History of AI in India\n\n* A. Early beginnings and milestones\n* B. Key players and institutions involved in AI research\n* C. Evolution over the years\n\nIII. Current Trends and Applications of AI in India\n\n* A. Healthcare: Examples and impact\n* B. Finance: Innovations and challenges\n* C. Education: Blurring lines with AI tools\n* D. Transportation: Autonomous vehicles and beyond\n* E. Other sectors like agriculture, manufacturing, etc.\n\nIV. Government Initiatives and Policies for AI Development\n\n* A. Programs and funding allocated for AI research\n* B. Collaborations with international organizations\n* C. Any regulatory frameworks or guidelines\n\nV. Education and Skill Development in AI\n\n* A. Academic programs at various levels\n* B. Non-formal training initiatives\n* C. Government and private sector involvement\n\nVI. Ethical Considerations and Challenges\n\n* A. Pri ...

# %%
print(final_state['outline'])
# Out:
# I've been tasked with creating a detailed outline for a blog about the rise of AI in India. I need to make sure that the content is informative, engaging, and covers all the key aspects of how artificial intelligence has impacted the country. Let me start by brainstorming some main points that should be included.
#
# First off, I think it's important to introduce what AI is and why it's significant, especially in a context like India. Maybe include some basic definitions and perhaps touch on its global impact as well. This will help readers who might not be familiar with the technology understand the importance of AI in today's world.
#
# Next, I should look into the history of AI development in India. When did it start? What were the initial milestones? Who are the key players or institutions involved in AI research and development here? Understanding the background can provide context for how far we've come and where we're headed.
#
# Moving on to current trends and applications of AI in India. This could include sectors like healthcare, finance, education, transportation, etc., where AI is making a significant impact. For each sector, I should mention specific examples or companies that are leading the way with AI solutions. It might also be useful to discuss any challenges these industries are facing due to AI implementation and how they're being addressed.
#
# Moreover, discussing the role of government in fostering AI development would be insightful. Are there any policies or initiatives launched by the Indian government to promote AI? How is funding being allocated for AI research and innovation? What about collaborations with international organizations or tech giants?
#
# Education and skill development are also crucial aspects. With AI becoming increasingly prevalent, there's a need for skilled workforce. I should look into programs that are in place to train people in AI-related skills, both at the undergraduate and graduate levels as well as through non-formal courses.
#
# Ethical considerations and challenges cannot be overlooked. As AI advances, there are issues related to privacy, job displacement, bias in algorithms, and more that need to be addressed. It would be valuable to explore these topics and see how India is tackling them.
#
# Furthermore, the impact of AI on society and economy is a broad topic. I should consider both sides—how AI is creating new opportunities and disrupting existing ones—and analyze whether it's leading to overall progress or inequality.
#
# In terms of structure, maybe start with an introduction to AI and its importance, followed by history in India, current trends, government initiatives, education and skill development, ethical considerations, impact on society and economy, and finally, a conclusion summarizing the key points and perhaps looking ahead to future prospects.
#
# Let me try sketching this out in a more organized way:
#
# I. Introduction
#
# * A. Brief explanation of AI
# * B. Significance of AI in today's world
# * C. Importance of studying AI in India
#
# II. History of AI in India
#
# * A. Early beginnings and milestones
# * B. Key players and institutions involved in AI research
# * C. Evolution over the years
#
# III. Current Trends and Applications of AI in India
#
# * A. Healthcare: Examples and impact
# * B. Finance: Innovations and challenges
# * C. Education: Blurring lines with AI tools
# * D. Transportation: Autonomous vehicles and beyond
# * E. Other sectors like agriculture, manufacturing, etc.
#
# IV. Government Initiatives and Policies for AI Development
#
# * A. Programs and funding allocated for AI research
# * B. Collaborations with international organizations
# * C. Any regulatory frameworks or guidelines
#
# V. Education and Skill Development in AI
#
# * A. Academic programs at various levels
# * B. Non-formal training initiatives
# * C. Government and private sector involvement
#
# VI. Ethical Considerations and Challenges
#
# * A. Privacy concerns and data protection
# * B. Job displacement and its impact on society
# * C. Bias in AI algorithms and mitigation strategies
# * D. Other ethical issues related to AI
#
# VII. Impact of AI on Society and Economy
#
# * A. Opportunities created by AI
# * B. Disruptions caused by AI
# * C. Discussion on overall progress or potential inequality
#
# VIII. Conclusion
#
# * A. Summary of key points
# * B. Future prospects and areas for further exploration
#
# This seems like a comprehensive outline. Now, I need to flesh out each section with detailed information. For instance, in the introduction, besides defining AI, I could talk about its applications in various industries and why it's crucial for India to be at the forefront of this technology.
#
# In the history section, I should research and include names of pioneers or institutions that have contributed significantly to AI development in India. This will not only honor their contributions but also inspire readers by showing how far Indian researchers have come.
#
# For current trends and applications, I need to gather data on companies using AI, any notable projects, and perhaps interview experts or industry leaders for firsthand insights. Visual aids like graphs or infographics could make the content more engaging.
#
# When discussing government initiatives, it's essential to provide concrete examples of policies or funding schemes that support AI research and development. Highlighting successful collaborations with international partners can also show India's commitment to global technological advancement.
#
# In the education section, I should look into universities offering courses in AI, any specializations or interdisciplinary programs, as well as online platforms and bootcamps that offer training in this field. It would be interesting to include statistics on enrollment or completion rates of these programs.
#
# Ethical considerations are a sensitive topic. I need to approach them with care, ensuring that all perspectives are considered without bias. Discussing both the positive and negative aspects can help readers understand the complexity of AI's impact and encourage informed discussion.
#
# When analyzing the impact on society and economy, it might be helpful to use case studies or examples from different sectors to illustrate how AI is changing things. This will make the abstract concepts more tangible for the readers.
#
# Finally, in the conclusion, I should bring all the points together and perhaps offer some thoughts on where India stands in the global landscape of AI development and what the future might hold.
#
# I think this outline provides a solid foundation for the blog post. Now, it's time to start researching and gathering more specific information for each section to make the content rich and reliable.
#
# **Final Outline**
#
# 1. **Introduction**
#    - A. Brief explanation of AI
#    - B. Significance of AI in today's world
#    - C. Importance of studying AI in India
#
# 2. **History of AI in India**
#    - A. Early beginnings and milestones
#    - B. Key players and institutions involved in AI research
#    - C. Evolution over the years
#
# 3. **Current Trends and Applications of AI in India**
#    - A. Healthcare: Examples and impact
#    - B. Finance: Innovations and challenges
#    - C. Education: Blurring lines with AI tools
#    - D. Transportation: Autonomous vehicles and beyond
#    - E. Other sectors like agriculture, manufacturing, etc.
#
# 4. **Government Initiatives and Policies for AI Development**
#    - A. Programs and funding allocated for AI research
#    - B. Collaborations with international organizations
#    - C. Regulatory frameworks or guidelines
#
# 5. **Education and Skill Development in AI**
#    - A. Academic programs at various levels
#    - B. Non-formal training initiatives
#    - C. Government and private sector involvement
#
# 6. **Ethical Considerations and Challenges**
#    - A. Privacy concerns and data protection
#    - B. Job displacement and its impact on society
#    - C. Bias in AI algorithms and mitigation strategies
#    - D. Other ethical issues related to AI
#
# 7. **Impact of AI on Society and Economy**
#    - A. Opportunities created by AI
#    - B. Disruptions caused by AI
#    - C. Discussion on overall progress or potential inequality
#
# 8. **Conclusion**
#    - A. Summary of key points
#    - B. Future prospects and areas for further exploration

# %%
print(final_state['content'])
# Out:
# Alright, I've got this task to write a blog about the rise of AI in India. I'm pretty excited because AI is such an interesting topic these days, and seeing how it's impacting different sectors here in India is really fascinating. So, first things first, I need to make sure that my blog is informative, engaging, and covers all the key aspects without overwhelming the readers.
#
# Let me start by thinking about what AI is and why it matters, especially in a country like India. I think starting with the basics would be helpful for those who aren't too familiar with technology jargon. So, in the introduction, I'll probably define AI—maybe say something like "Artificial Intelligence, or AI, refers to the simulation of human intelligence in machines that are programmed to think and learn like humans." Then, I can talk about its significance today, perhaps mentioning examples from different industries where AI is making a big difference.
#
# Next, I need to look into the history of AI development in India. When did it start? What were some of the early milestones? Who are the key players or institutions involved in AI research here? Understanding this background will help readers see how far we've come and what's ahead. Maybe I can include a timeline of major events or breakthroughs in Indian AI history.
#
# Moving on to current trends and applications, that seems like a broad but crucial section. I should pick a few sectors where AI is really making an impact—like healthcare, finance, education, transportation—and delve into specific examples within each one. For instance, in healthcare, maybe talk about how AI is being used for disease diagnosis or drug discovery. In finance, perhaps discuss AI-driven fraud detection or algorithmic trading. Education could be interesting because of the use of AI tools like chatbots and personalized learning platforms. Transportation might involve autonomous vehicles or smart traffic management systems.
#
# It's also important to consider any challenges these sectors are facing with AI implementation. Are there privacy issues in healthcare? Job displacement in transportation? I should research and mention these problems to provide a balanced view.
#
# Now, regarding government initiatives—this is something that could be really insightful for readers. How is the Indian government supporting AI development? Are there specific policies or funding schemes in place? Maybe there are collaborations with international organizations or tech giants that could give readers an idea of India's global standing in this area.
#
# Education and skill development are also key here. With AI becoming increasingly prevalent, there's a growing need for skilled workforce. I should look into programs at various educational levels—undergraduate, graduate, and even non-formal training options—for AI-related skills. It would be great to include some statistics on enrollment or success rates of these programs.
#
# Ethical considerations are inevitable when discussing AI. Issues like privacy concerns, bias in algorithms, job displacement—the list goes on. I need to approach this with care, making sure to present multiple perspectives and discuss how India is tackling these challenges.
#
# Lastly, the impact of AI on society and economy is a broad topic. On one hand, AI brings about new opportunities—faster processing, improved efficiency, innovation in various fields. On the other hand, there are disruptions—some jobs might become obsolete, there could be ethical concerns like privacy invasion. It would be valuable to analyze whether overall, AI leads to progress or potential inequality.
#
# In terms of structure, I think starting with an introduction that hooks the reader and sets the stage is important. Then, diving into history provides context, followed by current trends for a snapshot of what's happening now. Government initiatives show support and direction, education and skill development address the workforce needs, ethical considerations provide depth, and finally, analyzing the impact gives readers a comprehensive view.
#
# I need to make sure that each section flows logically into the next and that I'm not overwhelming the readers with too much information at once. Maybe using subheadings or bullet points for certain sections could help organize the content better.
#
# Also, incorporating data and statistics where possible would strengthen my points. For example, if there's a particular statistic on how AI has increased efficiency in a certain sector, that would be great to include.
#
# Visual aids like graphs or infographics could also make the blog more engaging. Perhaps I can find some relevant images or charts that illustrate the growth of AI in India or its impact on different industries.
#
# I should also consider including quotes from experts or industry leaders to add credibility and personal insights into the topic. This would not only provide diverse perspectives but also make the content more relatable to readers.
#
# In conclusion, I need to summarize the key points and perhaps look ahead to future prospects for AI in India. Maybe touch on any upcoming projects or technologies that are set to shape the country's AI landscape.
#
# Overall, my goal is to create a blog that not only informs but also engages and inspires readers about the potential of AI in India.
#
# **Final Outline**
#
# 1. **Introduction**
#    - A. Brief explanation of AI
#    - B. Significance of AI in today's world
#    - C. Importance of studying AI in India
#
# 2. **History of AI in India**
#    - A. Early beginnings and milestones
#    - B. Key players and institutions involved in AI research
#    - C. Evolution over the years
#
# 3. **Current Trends and Applications of AI in India**
#    - A. Healthcare: Examples and impact
#    - B. Finance: Innovations and challenges
#    - C. Education: Blurring lines with AI tools
#    - D. Transportation: Autonomous vehicles and beyond
#    - E. Other sectors like agriculture, manufacturing, etc.
#
# 4. **Government Initiatives and Policies for AI Development**
#    - A. Programs and funding allocated for AI research
#    - B. Collaborations with international organizations
#    - C. Regulatory frameworks or guidelines
#
# 5. **Education and Skill Development in AI**
#    - A. Academic programs at various levels
#    - B. Non-formal training initiatives
#    - C. Government and private sector involvement
#
# 6. **Ethical Considerations and Challenges**
#    - A. Privacy concerns and data protection
#    - B. Job displacement and its impact on society
#    - C. Bias in AI algorithms and mitigation strategies
#    - D. Other ethical issues related to AI
#
# 7. **Impact of AI on Society and Economy**
#    - A. Opportunities created by AI
#    - B. Disruptions caused by AI
#    - C. Discussion on overall progress or potential inequality
#
# 8. **Conclusion**
#    - A. Summary of key points
#    - B. Future prospects and areas for further exploration
